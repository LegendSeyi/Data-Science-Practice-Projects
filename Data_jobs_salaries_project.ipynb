# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('ds_salaries.csv')
dataset
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
residence = dataset['employee_residence']

# %%
residence.unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'PL',
#        'PT', 'CN', 'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'PH', 'ES',
#        'DK', 'RU', 'IT', 'HR', 'BG', 'SG', 'BR', 'IQ', 'VN', 'BE', 'UA',
#        'MT', 'CL', 'RO', 'IR', 'CO', 'MD', 'KE', 'SI', 'HK', 'TR', 'RS',
#        'PR', 'LU', 'JE', 'CZ', 'AR', 'DZ', 'TN', 'MY', 'EE', 'AU', 'BO',
#        'IE', 'CH'], dtype=object)

# %%
#Getting the info for data analyst Jobs in United state

# %%
dataset_US = dataset.loc[dataset['employee_residence']=='US']

# %%
dataset_US
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# 6             6       2020               SE              FT
# 8             8       2020               MI              FT
# 13           13       2020               MI              FT
# ..          ...        ...              ...             ...
# 599         599       2022               MI              FT
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 4    Machine Learning Engineer  150000             USD         150000
# 5                 Data Analyst   72000             USD          72000
# ...

# %%
dataset_US.describe()
# Out:
#        Unnamed: 0    work_year         salary  salary_in_usd  remote_ratio
# count  332.000000   332.000000     332.000000     332.000000    332.000000
# mean   346.283133  2021.587349  149804.852410  149194.117470     77.259036
# std    171.327176     0.627821   68184.420694   68282.111763     40.420962
# min      4.000000  2020.000000   25000.000000   25000.000000      0.000000
# 25%    213.500000  2021.000000  106195.000000  105850.000000     50.000000
# 50%    350.500000  2022.000000  139300.000000  138475.000000    100.000000
# 75%    498.750000  2022.000000  175025.000000  175000.000000    100.000000
# max    605.000000  2022.000000  600000.000000  600000.000000    100.000000

# %%
dataset_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332 entries, 4 to 605
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          332 non-null    int64
#  1   work_year           332 non-null    int64
#  2   experience_level    332 non-null    object
#  3   employment_type     332 non-null    object
#  4   job_title           332 non-null    object
#  5   salary              332 non-null    int64
#  6   salary_currency     332 non-null    object
#  7   salary_in_usd       332 non-null    int64
#  8   employee_residence  332 non-null    object
#  9   remote_ratio        332 non-null    int64
#  10  company_location    332 non-null    object
#  11  company_size        332 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 33.7+ KB

# %%
#Using EDA

# %%
sns.countplot(x='company_size',data=dataset_US)
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='count'>

# %%
sns.countplot(x='employment_type',data=dataset_US)
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='count'>

# %%
sns.countplot(x='experience_level',data=dataset_US)
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='count'>

# %%
dataset_US['salary'].mean()
# Out:
# 149804.85240963855

# %%
dataset_US[dataset_US['salary']== 600000]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 252  Principal Data Engineer  600000             USD         600000
#
#     employee_residence  remote_ratio company_location company_size
# 252                 US           100               US            L

# %%
dataset_US.boxplot(column='salary', by='experience_level')
# Out:
# <AxesSubplot:title={'center':'salary'}, xlabel='experience_level'>

# %%
dataset_US.boxplot(column='salary', by='company_size')
# Out:
# <AxesSubplot:title={'center':'salary'}, xlabel='company_size'>

# %%
ex_level = dataset_US.groupby('experience_level').corr()
ex_level
# Out:
#                                 Unnamed: 0  work_year    salary  \
# experience_level
# EN               Unnamed: 0       1.000000   0.903460 -0.077801
#                  work_year        0.903460   1.000000 -0.120969
#                  salary          -0.077801  -0.120969  1.000000
#                  salary_in_usd   -0.077801  -0.120969  1.000000
#                  remote_ratio    -0.217837  -0.238171 -0.139737
# EX               Unnamed: 0       1.000000   0.866577 -0.274508
#                  work_year        0.866577   1.000000 -0.579522
#                  salary          -0.274508  -0.579522  1.000000
#                  salary_in_usd   -0.274508  -0.579522  1.000000
#                  remote_ratio     0.269546   0.262445 -0.000018
# MI               Unnamed: 0       1.000000   0.883517 -0.084987
#                  work_year        0.883517   1.000000 -0.059547
#                  salary          -0.084987  -0.059547  1.000000
# ...

# %%
dataset_US.groupby('experience_level').corr().loc['EN']
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.903460 -0.077801      -0.077801     -0.217837
# work_year        0.903460   1.000000 -0.120969      -0.120969     -0.238171
# salary          -0.077801  -0.120969  1.000000       1.000000     -0.139737
# salary_in_usd   -0.077801  -0.120969  1.000000       1.000000     -0.139737
# remote_ratio    -0.217837  -0.238171 -0.139737      -0.139737      1.000000

# %%
ax_for_EN = sns.heatmap(ex_level.loc['EN'],annot=True)

# %%
#we are using the experience level to make prediction for the salaries
