# %%
import twint
import pandas as pd
import os
import snscrape.modules.twitter as sntwitter
import tweepy

# %%
#comment note
#tweets_df1 = ASUU
#tweets_df2 = Chelsea
#tweets_df3 = Nigeria
#tweets_df4 = Buhari

# %%
#ASUU DATAframe

# %%
tweets_list1 = []


for i,tweet in enumerate(sntwitter.TwitterSearchScraper('ASUU').get_items()):
    if i>100:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

    
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_list1
# Out:
# [[datetime.datetime(2022, 7, 30, 19, 50, 9, tzinfo=datetime.timezone.utc),
#   1553468008391114752,
#   'Just reminded me of the noodles I buy in school…ASUU please 😭 https://t.co/41nj01loY9',
#   'somah_ski'],
#  [datetime.datetime(2022, 7, 30, 19, 49, 35, tzinfo=datetime.timezone.utc),
#   1553467862987202571,
#   '@doin2much_ So for university education, there’s private schools and public schools, owned by the government. The union of staff in the public schools are known as ASUU. It’s an acronym. They’re currently on strike, but private schools are still in session. The dunce OP quoted is graduating-',
#   'tumininubizzle'],
#  [datetime.datetime(2022, 7, 30, 19, 49, 18, tzinfo=datetime.timezone.utc),
#   1553467791889547264,
# ...

# %%
tweets_df1.head(100)
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-07-30 19:50:09+00:00  1553468008391114752
# 1  2022-07-30 19:49:35+00:00  1553467862987202571
# 2  2022-07-30 19:49:18+00:00  1553467791889547264
# 3  2022-07-30 19:48:38+00:00  1553467624482545664
# 4  2022-07-30 19:48:20+00:00  1553467550079533056
# ..                       ...                  ...
# 95 2022-07-30 19:07:53+00:00  1553457368402464768
# 96 2022-07-30 19:07:23+00:00  1553457242644660230
# 97 2022-07-30 19:07:11+00:00  1553457195521609729
# 98 2022-07-30 19:07:06+00:00  1553457172964671490
# 99 2022-07-30 19:06:29+00:00  1553457016424861700
#
#                                                  Text         Username
# 0   Just reminded me of the noodles I buy in schoo...        somah_ski
# 1   @doin2much_ So for university education, there...   tumininubizzle
# 2   We are a Company that offers a variety of clea...        Kachiie__
# 3         @CounterAtackk @BetaKopites Wkwkwkwkwk asuu     ariefrusdian
# ...

# %%
tweets_df1.to_csv(""+"Tweets_Asuu2.csv")

# %%
tweets_df1['Username'].head(5)
# Out:
# 0           FollowMania8
# 1        jaiyeoriestyle_
# 2            ola_forward
# 3                abbyfav
# 4          PleasureOlie1
#               ...
# 9996         OluWasEdAgO
# 9997            seyivine
# 9998           RemmyAlex
# 9999             wakmoer
# 10000            okwoche
# Name: Username, Length: 10001, dtype: object

# %%
tweets_df1.Username.value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
tweets_df1['Username'].head(10)
# Out:
# 0       FollowMania8
# 1    jaiyeoriestyle_
# 2        ola_forward
# 3            abbyfav
# 4      PleasureOlie1
# 5           Ugotstan
# 6        YAZEEE_JIRI
# 7          ASUU_NGN_
# 8           BetplusN
# 9           vinimowo
# Name: Username, dtype: object

# %%
#What do we use value_counts() for?
#Answer
#  The function of value_counts() is for assigning values to objects in the way that the objects are arranged
#  in descending order so that the first object is the mod or the most frequent occuring element.

# %%
tweets_df1.iloc[10000]
# Out:
# Datetime                            2012-02-01 11:11:28+00:00
# Tweet Id                                   164667174911356928
# Text        Reports from #Nigeria say #University lectcure...
# Username                                              okwoche
# Name: 10000, dtype: object

# %%
tweets_df1['Datetime'].head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-94e9a3b567db> in <module>
# ----> 1 tweets_df1['Datetime'].head(5)
#
# NameError: name 'tweets_df1' is not defined

# %%
#CHELSEA DATAframe

# %%
#Generating tweets on chelsea

tweets_list2 = []


for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:#Chelsea').get_items()):
    if i>10000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

    
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_list2
# Out:
# [[datetime.datetime(2022, 7, 28, 14, 38, 33, tzinfo=datetime.timezone.utc),
#   1552664814010466305,
#   'We will never recover from this transfer window #chelsea https://t.co/rRKtpDNKxq',
#   'djkydthamaze'],
#  [datetime.datetime(2022, 7, 28, 14, 32, 37, tzinfo=datetime.timezone.utc),
#   1552663321211453441,
#   'Reece James.💙\n\nAre you ready for this guy?\n#chelsea https://t.co/Tf6YOTGq2R',
#   'the_clemo'],
#  [datetime.datetime(2022, 7, 28, 14, 30, 18, tzinfo=datetime.timezone.utc),
#   1552662738630979584,
#   "Chillwell is back from long term injury which is very risky.\n\nThiago Silva and Azpilicueta are aging. We are not sure his they will cope this season.\n\nKoulibally is unproven in the EPL. \nSo it's a wait and see for the Chelsea defence.⏱️\n#EPL #Chelsea #FPLCommunity #football",
#   'Fpl_Meno'],
#  [datetime.datetime(2022, 7, 28, 14, 27, 44, tzinfo=datetime.timezone.utc),
#   1552662091219304449,
# ...

# %%
tweets_df2
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-07-28 14:38:33+00:00  1552664814010466305
# 1     2022-07-28 14:32:37+00:00  1552663321211453441
# 2     2022-07-28 14:30:18+00:00  1552662738630979584
# 3     2022-07-28 14:27:44+00:00  1552662091219304449
# 4     2022-07-28 14:12:25+00:00  1552658235659735045
# ...                         ...                  ...
# 9996  2022-03-10 14:09:38+00:00  1501923237852241924
# 9997  2022-03-10 14:09:29+00:00  1501923199285702657
# 9998  2022-03-10 14:05:17+00:00  1501922143206244357
# 9999  2022-03-10 14:04:59+00:00  1501922064692826114
# 10000 2022-03-10 14:03:28+00:00  1501921682327584770
#
#                                                     Text        Username
# 0      We will never recover from this transfer windo...    djkydthamaze
# 1      Reece James.💙\n\nAre you ready for this guy?\n...       the_clemo
# 2      Chillwell is back from long term injury which ...        Fpl_Meno
# ...

# %%
tweets_df2.Username.value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#NIGERIA DATAframe

# %%
tweets_list3 = []


for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:#Nigeria').get_items()):
    if i>10000:
        break
    tweets_list3.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

    
tweets_df3 = pd.DataFrame(tweets_list3, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df3
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-07-28 15:14:34+00:00  1552673879281238019
# 1     2022-07-28 15:00:47+00:00  1552670411233656832
# 2     2022-07-28 14:54:30+00:00  1552668829880389632
# 3     2022-07-28 14:42:24+00:00  1552665782391570432
# 4     2022-07-28 14:42:23+00:00  1552665780462186496
# ...                         ...                  ...
# 9996  2022-04-11 06:46:39+00:00  1513408167484526601
# 9997  2022-04-11 06:41:02+00:00  1513406752489844741
# 9998  2022-04-11 06:31:17+00:00  1513404299589603333
# 9999  2022-04-11 06:12:01+00:00  1513399452274511872
# 10000 2022-04-11 06:09:56+00:00  1513398927063756807
#
#                                                     Text         Username
# 0      Strategy is key in the accomplishment of busin...      Saa_consult
# 1      🏅Contest opportunity 🏅 \nThe Diamond Awards fo...            IJNet
# 2      #Algerian #energy minister already signed a me...        kmldial70
# ...

# %%
tweets_df3['Text'].head(10)
# Out:
# 0    Strategy is key in the accomplishment of busin...
# 1    🏅Contest opportunity 🏅 \nThe Diamond Awards fo...
# 2    #Algerian #energy minister already signed a me...
# 3    He also mentioned that the #EU #imports 14% of...
# 4    as well as the bloc's #commitment to transform...
# 5    Dear @renoomokri, \n\nA young Nigerian applied...
# 6    Recommended read: Fantastic report from \n@Lee...
# 7    Let there  be a law that  will ban all the #po...
# 8    Ademola Lookman 🇳🇬 is set to join Atalanta on ...
# 9    Attacks on the Christian community in #Nigeria...
# Name: Text, dtype: object

# %%
tweets_df3.Username.value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#BUHARI DATAframe

# %%
tweets_list4 = []


for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:#Buhari').get_items()):
    if i>10000:
        break
    tweets_list4.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

    
tweets_df4 = pd.DataFrame(tweets_list4, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df4
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-07-28 13:44:26+00:00  1552651195587538944
# 1     2022-07-28 12:57:44+00:00  1552639441482780673
# 2     2022-07-28 12:34:43+00:00  1552633652273717248
# 3     2022-07-28 11:48:14+00:00  1552621953126748162
# 4     2022-07-28 10:03:13+00:00  1552595523940540420
# ...                         ...                  ...
# 9996  2019-01-17 08:36:31+00:00  1085818134097842176
# 9997  2019-01-17 08:20:58+00:00  1085814220657225729
# 9998  2019-01-17 08:12:11+00:00  1085812010686861313
# 9999  2019-01-17 07:24:37+00:00  1085800038775881728
# 10000 2019-01-17 06:37:36+00:00  1085788208473034752
#
#                                                     Text        Username
# 0      [#ICYMI] Massive resignation from banks as eng...       abati1990
# 1      For our own eyes the Senate President is prote...    bello_Tbabtz
# 2      If insufficient money is stopping you from pro...     jonatvictor
# ...

# %%
tweets_df4.iloc[10]
# Out:
# Datetime                            2022-07-27 23:33:43+00:00
# Tweet Id                                  1552437104659283969
# Text        Forget about the Senate impeachment propaganda...
# Username                                         SmartObinna9
# Name: 10, dtype: object

# %%
tweets_df4['Text'].head(10)
# Out:
# 0    [#ICYMI] Massive resignation from banks as eng...
# 1    For our own eyes the Senate President is prote...
# 2    If insufficient money is stopping you from pro...
# 3    Presido bubu Dey face impeachment threat from ...
# 4    @Oserume1 @Waspapping_ This classic taqiyya, n...
# 5    🛍 👗 🇬🇧 @Boohoo from 🇰🇪 🇳🇬 🇬🇭 UK-DUKAS  \nPay i...
# 6    @toluogunlesi @PeterObi What’s wrong in going ...
# 7    I am absolutely 'obidient'..we need to save Ni...
# 8    If you do not plant🌱🌴🌿☘🌵🎄🌲🍀💐🌾🎋🍃🍂🍁you will spen...
# 9    How is Abubakar Duduwale, the man who trekked ...
# Name: Text, dtype: object
